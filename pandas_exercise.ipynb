# %%
import pandas as pd

# %%
iris = pd.read_csv("D:/[APPLIED] GATE/[CodingNinjas] All Courses/[Coding Ninjas] Machine Learning and Data Science/12. Lecture 12 - Pandas/16-17 & 19/iris.csv")

# %%
cp = iris.copy()

# %%
cp.head() ## Setosa Versicolor Virginica
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
cp.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(cp.shape)
print(cp.dtypes)
print(cp.columns)
# Out:
# (150, 5)
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %% [markdown]
# ## Count of Flower

# %%
variety_Setosa = cp[cp.variety == "Setosa"]

variety_Versicolor = cp[cp.variety == "Versicolor"]

variety_Virginica = cp[cp.variety == "Virginica"]

print(len(variety_Setosa), len(variety_Versicolor), len(variety_Virginica))
# Out:
# 50 50 50

# %% [markdown]
# ## Its Virginica

# %%
variety_virginica = variety_Virginica[variety_Virginica['petal.length']> 1.5]
print(variety_virginica)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %% [markdown]
# ## Iris Value

# %%
sl1_min = variety_Setosa["sepal.length"].min()
sw1_min = variety_Setosa["sepal.width"].min()
pl1_min = variety_Setosa["petal.length"].min()
pw1_min = variety_Setosa["petal.width"].min()
vr1_min = variety_Setosa["variety"].min()

sl1_max = variety_Setosa["sepal.length"].max()
sw1_max = variety_Setosa["sepal.width"].max()
pl1_max = variety_Setosa["petal.length"].max()
pw1_max = variety_Setosa["petal.width"].max()
vr1_max = variety_Setosa["variety"].max()

sl1_avg = variety_Setosa["sepal.length"].mean()
sw1_avg = variety_Setosa["sepal.width"].mean()
pl1_avg = variety_Setosa["petal.length"].mean()
pw1_avg = variety_Setosa["petal.width"].mean()
# vr1_avg = variety_Setosa["variety"].mean()

sl2_min = variety_Versicolor["sepal.length"].min()
sw2_min = variety_Versicolor["sepal.width"].min()
pl2_min = variety_Versicolor["petal.length"].min()
pw2_min = variety_Versicolor["petal.width"].min()
vr2_min = variety_Versicolor["variety"].min()

sl2_max = variety_Versicolor["sepal.length"].max()
sw2_max = variety_Versicolor["sepal.width"].max()
pl2_max = variety_Versicolor["petal.length"].max()
pw2_max = variety_Versicolor["petal.width"].max()
vr2_max = variety_Versicolor["variety"].max()

sl2_avg = variety_Versicolor["sepal.length"].mean()
sw2_avg = variety_Versicolor["sepal.width"].mean()
pl2_avg = variety_Versicolor["petal.length"].mean()
pw2_avg = variety_Versicolor["petal.width"].mean()
# vr2_avg = variety_Versicolor["variety"].mean()

sl3_min = variety_Virginica["sepal.length"].min()
sw3_min = variety_Virginica["sepal.width"].min()
pl3_min = variety_Virginica["petal.length"].min()
pw3_min = variety_Virginica["petal.width"].min()
vr3_min = variety_Virginica["variety"].min()

sl3_max = variety_Virginica["sepal.length"].max()
sw3_max = variety_Virginica["sepal.width"].max()
pl3_max = variety_Virginica["petal.length"].max()
pw3_max = variety_Virginica["petal.width"].max()
vr3_max = variety_Virginica["variety"].max()

sl3_avg = variety_Virginica["sepal.length"].mean()
sw3_avg = variety_Virginica["sepal.width"].mean()
pl3_avg = variety_Virginica["petal.length"].mean()
pw3_avg = variety_Virginica["petal.width"].mean()
# vr3_avg = variety_Virginica["variety"].mean()


print(sl1_min, sw1_min, pl1_min, pw1_min, vr1_min)
print(sl1_max, sw1_max, pl1_max, pw1_max, vr1_max)
print(sl1_avg.round(2), sw1_avg.round(2), pl1_avg.round(2), pw1_avg.round(2), vr1_max)

print(sl2_min, sw2_min, pl2_min, pw2_min, vr2_min)
print(sl2_max, sw2_max, pl2_max, pw2_max, vr2_max)
print(sl2_avg.round(2), sw2_avg.round(2), pl2_avg.round(2), pw2_avg.round(2), vr2_max)


print(sl3_min, sw3_min, pl3_min, pw3_min, vr3_min)
print(sl3_max, sw3_max, pl3_max, pw3_max, vr3_max)
print(sl3_avg.round(2), sw3_avg.round(2), pl3_avg.round(2), pw3_avg.round(2), vr3_max)
# Out:
# 4.3 2.3 1.0 0.1 Setosa
# 5.8 4.4 1.9 0.6 Setosa
# 5.01 3.43 1.46 0.25 Setosa
# 4.9 2.0 3.0 1.0 Versicolor
# 7.0 3.4 5.1 1.8 Versicolor
# 5.94 2.77 4.26 1.33 Versicolor
# 4.9 2.2 4.5 1.4 Virginica
# 7.9 3.8 6.9 2.5 Virginica
# 6.59 2.97 5.55 2.03 Virginica

# %% [markdown]
# # Terrorism  Data

# %%
td = pd.read_csv("D:/[APPLIED] GATE/[CodingNinjas] All Courses/[Coding Ninjas] Machine Learning and Data Science/12. Lecture 12 - Pandas/24. Assignment/terrorismData.csv")

# %%
td.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
td.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
td.tail()
# Out:
#         Year  Month  Day      Country            State  \
# 181686  2017     12   31      Somalia  Middle Shebelle
# 181687  2017     12   31        Syria         Lattakia
# 181688  2017     12   31  Philippines      Maguindanao
# 181689  2017     12   31        India          Manipur
# 181690  2017     12   31  Philippines      Maguindanao
#
#                             Region           City   Latitude   Longitude  \
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                             AttackType  Killed  Wounded            Target  \
# 181686                   Armed Assault     1.0      2.0        Checkpoint
# ...
